# %%
import random
import math
import statistics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Coin Flip results for 100000 sets of 1000, or whatever numbers you want

def coin_flip(heads_list, tails_list, ratio_list):
    flips = int(input("How many coin flips? "))
    loops = int(input("How many sets of coin flip data? "))
    for r in range(loops):
        heads = 0
        tails = 0
        for i in range(flips):
            if random.random() > .5:
                heads += 1
            else:
                tails +=1
        heads_list.append(heads)
        tails_list.append(tails)
        ratio_list.append(heads / 1000)

def diff_between(heads_list, tails_list, diff_list):
    for i in range(17):
        _ = abs(heads_list[i] - tails_list[i])
        diff_list.append(_)
    return


def find_ratio(heads_list, tails_list, ratio_list):
    for i in range(100000):
        _ = (heads_list[i] / total_flips[i])
        ratio_list.append(_)
    return
    
    
heads_list = []
tails_list = []
diff_list = []
ratio_list = []

coin_flip(heads_list, tails_list, ratio_list)
# diff_between(heads_list, tails_list, diff_list)
# find_ratio(heads_list, tails_list, ratio_list)

print(heads_list[1])
print(tails_list[1])
print(ratio_list[1])
# Out:
# How many coin flips? 100
# How many sets of coin flip data? 100000
# 56
# 44
# 0.056

# %%
# well that takes a while to generate

# %%
y1 = ratio_list

x1 = range(100000)
plt.hist(ratio_list, bins=1000)

# plt.yscale('log')
# plt.xticks(range(17), x1)
# plt.ylabel("Difference between Heads & Tails")
# plt.xlabel("2**x Flips")
# plt.title("Tracking Coin Toss Results")
plt.show()

# %%
plt.scatter(x1, y1)
# plt.xscale('log',)
# plt.xticks(range(17), x1)
# plt.ylabel("Difference between Heads & Tails")
# plt.xlabel("2**x flips")
plt.title("100000 is a lot of dots")
plt.show()
